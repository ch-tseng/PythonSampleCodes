# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys

# %%
# !wget http://www.music.helsinki.fi/tmt/opetus/uusmedia/esim/a2002011001-e02-8kHz.wav
spf = wave.open('a2002011001-e02-8kHz.wav','r')
# Out:
# --2018-05-06 08:52:23--  http://www.music.helsinki.fi/tmt/opetus/uusmedia/esim/a2002011001-e02-8kHz.wav
# Resolving www.music.helsinki.fi (www.music.helsinki.fi)... 128.214.222.15
# Connecting to www.music.helsinki.fi (www.music.helsinki.fi)|128.214.222.15|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1738016 (1.7M) [audio/x-wav]
# Saving to: ‘a2002011001-e02-8kHz.wav’
#
# a2002011001-e02-8kH 100%[===================>]   1.66M   325KB/s    in 5.9s
#
# 2018-05-06 08:52:31 (287 KB/s) - ‘a2002011001-e02-8kHz.wav’ saved [1738016/1738016]

# %%
#Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.frombuffer(signal, 'Int16')
# Out:
# /home/chtseng/.virtualenvs/dp/lib/python3.5/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#If Stereo
if spf.getnchannels() == 2:
    print('Just mono files')
    #sys.exit(0)

plt.figure(1)
plt.title('Signal Wave...')
plt.plot(signal)
plt.show()
# Out:
# Just mono files

# %%
import os
import wave

import pylab

def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

# %%
graph_spectrogram("a2002011001-e02-8kHz.wav")
# Out:
# /home/chtseng/.virtualenvs/dp/lib/python3.5/site-packages/ipykernel_launcher.py:16: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   app.launch_new_instance()
